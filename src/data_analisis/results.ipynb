# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
figsize = (15, 10)

labels = {
    'protonet': 'Prototypical Networks',
    'densenet': 'DenseNet',
    'maml': 'MAML',
    'maml+cifar10': 'MAML + CIFAR10',
    'maml+mnist': 'MAML + MNIST',
    'maml+ciarp': 'MAML + CIARP',
    'maml+lsa16': 'MAML + LSA16',
    'maml+rwth': 'MAML + RWTH',
    'tl+cifar10': 'TL + CIFAR10',
    'tl+mnist': 'TL + MNIST',
    'tl+ciarp': 'TL + CIARP',
    'tl+lsa16': 'TL + LSA16',
    'tl+rwth': 'TL + RWTH'
}

colors = {
    'protonet': '#581845',
    'densenet': '#C70039',
    'maml': '#EE4266',
    'maml+cifar10': '#F45733',
    'maml+mnist': '#F36743',
    'maml+ciarp': '#F27753',
    'maml+lsa16': '#F18763',
    'maml+rwth': '#F09773',
    'tl+cifar10': '#80A4ED',
    'tl+mnist': '#80A4ED',
    'tl+ciarp': '#80A4ED',
    'tl+lsa16': '#80A4ED',
    'tl+rwth': '#80A4ED'
}

markerfacecolors=colors

# %%
# Results for each dataset as pandas DataFrame

lsa16 = pd.DataFrame({
    'samples': [5, 10, 15, 20, 30],
    'densenet_acc': [6.56, 92.80, 92.81, 95.31, 96.13],
    'densenet_std': [0.63, 2.89, 2.82, 1.23, 0],
    'maml_acc': [6.53, 93.95, 93.54, 95.72, 97.81],
    'maml_std': [0.2, 1.53, 1.6, 1, 0.38],
    'maml+cifar10_acc': [6.25, 92.18, 94.06, 95.63, 97.08],
    'maml+cifar10_std': [0, 1.47, 1.76, 2.6, 0.77],
    'maml+mnist_acc': [6.45, 92.91, 94.17, 95.63, 97.08],
    'maml+mnist_std': [0.41, 0.96, 2.45, 1.16, 0.41],
    'maml+ciarp_acc': [6.77, 92.08, 94.58, 96.14, 96.97],
    'maml+ciarp_std': [0.65, 2.51, 1.16, 1.34, 1.25],
    'maml+rwth_acc': [6.87, 92.81, 94.47, 94.37, 96.24],
    'maml+rwth_std': [0.76, 0.51, 2.29, 2.58, 1],
    'tl+cifar10_acc': [6.25, 92.91, 93.75, 94.79, 97.91],
    'tl+cifar10_std': [0, 2.66, 2.3, 1.14, 0.46],
    'tl+mnist_acc': [6.25, 92.60, 93.43, 95.41, 97.08],
    'tl+mnist_std': [0, 2.07, 1.73, 2.42, 0.62],
    'tl+ciarp_acc': [6.77, 92.08, 94.58, 96.14, 96.97],
    'tl+ciarp_std': [0, 1.77, 1.87, 1.12, 1.48],
    'tl+rwth_acc': [6.97, 74.79, 93.43, 95.62, 96.97],
    'tl+rwth_std': [1.45, 34.27, 2.56, 1.21, 0.89],
    'protonet_acc': [94.15, 94.64, 95.50, 97.20, 98.38],
    'protonet_std': [1.27, 1.23, 1.01, 0.74, 0.22],
})

ciarp = pd.DataFrame({
    'samples': [5, 10, 15, 20, 30, 40, 100, 360],
    'densenet_acc': [10, 10, 37.26, 76.07, 82.71, 99.83, 99.95, 99.83],
    'densenet_std': [0, 0, 36.81, 37.87, 38.35, 0.28, 0.04, 0.24],
    'maml_acc': [11.12, 26.53, 80.23, 98.85, 99.71, 99.56, 99.94, 99.01],
    'maml_std': [2.24, 33.07, 35.13, 0.99, 0.15, 0.34, 0.04, 0.66],
    'maml+cifar10_acc': [10.17, 10, 95.51, 98.41, 99.73, 98.92, 99.96, 99.44],
    'maml+cifar10_std': [0.94, 0, 2.15, 1.16, 0.3, 1.72, 0.02, 0.38],
    'maml+mnist_acc': [10, 12.70, 80.13, 98.91, 99.64, 99.74, 99.97, 99.43],
    'maml+mnist_std': [0, 3.27, 35.07, 0.47, 0.16, 0.16, 0.04, 0.64],
    'maml+lsa16_acc': [11.38, 11.44, 80.10, 98.95, 99.51, 99.50, 99.93, 99.30],
    'maml+lsa16_std': [2.65, 2.49, 35.07, 0.64, 0.45, 0.62, 0.08, 0.61],
    'maml+rwth_acc': [10, 10, 97.75, 99.07, 99.64, 99.65, 99.97, 99.08],
    'maml+rwth_std': [0, 0, 0.52, 0.63, 0.18, 0.17, 0.02, 0.73],
    'tl+cifar10_acc': [11.69, 27.24, 98.44, 98.71, 99.61, 99.64, 99.92, 99.59],
    'tl+cifar10_std': [3.39, 33.54, 0.47, 0.72, 0.21, 0.31, 0.05, 0.19],
    'tl+mnist_acc': [10, 10, 97.31, 99.25, 99.30, 99.70, 99.95, 99.21],
    'tl+mnist_std': [0, 0, 1.36, 0.37, 0.48, 0.31, 0.04, 0.51],
    'tl+lsa16_acc': [11.19, 10.01, 97.82, 99.07, 99.51, 99.73, 99.93, 99.73],
    'tl+lsa16_std': [2.38, 0.02, 0.93, 0.45, 0.24, 0.33, 0.06, 0.26],
    'tl+rwth_acc': [10.24, 10.03, 98.59, 98.33, 99.58, 99.74, 99.85, 99.42],
    'tl+rwth_std': [0.49, 0.04, 0.83, 1.16, 0.2, 0.16, 0.09, 0.40],
    'protonet_acc': [91.45, 94.48, 95.70, 97.63, 98.38, 99.21, 99.82, 99.41],
    'protonet_std': [2.44, 1.78, 0.66, 0.68, 0.27, 0.28, 0.05, 0.16],
})

rwth = pd.DataFrame({
    'samples': [5, 10, 15, 20, 30, 40, 50],
    'densenet_acc': [10.32, 17.78, 46.66, 64.59, 71.20, 71.85, 96.05],
    'densenet_std': [2.48, 17.08, 19.17, 3.81, 2.24, 3.84, 0.96],
    'maml_acc': [9.20, 9.86, 25.38, 30.51, 67.81, 67.13, 95.54],
    'maml_std': [1.97, 1.29, 19.31, 24.03, 1.99, 1.55, 1.21],
    'maml+cifar10_acc': [8.36, 9.69, 8.66, 38.90, 64.56, 64.53, 96.08],
    'maml+cifar10_std': [0.62, 1.94, 1.75, 24.40, 7.86, 3.18, 0.37],
    'maml+mnist_acc': [9.80, 9.80, 28.33, 51.12, 66.93, 69.07, 95.73],
    'maml+mnist_std': [1.27, 2.03, 21.66, 21.42, 3.13, 4.66, 0.56],
    'maml+ciarp_acc': [9.83, 17.59, 19.15, 38.57, 66.50, 66.36, 96.00],
    'maml+ciarp_std': [2.80, 16.62, 18.97, 23.35, 3.05, 3.02, 0.35],
    'maml+lsa16_acc': [10.98, 15.16, 28.57, 46.96, 67.18, 64.42, 95.48],
    'maml+lsa16_std': [3.66, 11.85, 23.10, 19.03, 4.49, 3.58, 1.29],
    'tl+cifar10_acc': [10.73, 17.78, 18.25, 48.19, 65.76, 66.28, 95.29],
    'tl+cifar10_std': [1.59, 17.21, 16.33, 21.08, 6.50, 4.67, 1.22],
    'tl+mnist_acc': [9.89, 17.32, 21.12, 37.13, 64.91, 63.66, 96.16],
    'tl+mnist_std': [1.49, 15.89, 18.70, 24.93, 3.54, 3.86, 0.58],
    'tl+ciarp_acc': [9.31, 18.30, 25.79, 39.07, 64.26, 66.69, 95.57],
    'tl+ciarp_std': [1.90, 16.49, 21.30, 24.93, 5.42, 3.15, 1.06],
    'tl+lsa16_acc': [8.33, 17.15, 28.93, 46.22, 66.58, 62.89, 95.48],
    'tl+lsa16_std': [0, 15.69, 24.06, 20.08, 5.00, 10.14, 0.30],
    'protonet_acc': [48.93, 48.53, 48.87, 46.73, 47.58, 50.36, 48.09],
    'protonet_std': [3.02, 1.59, 1.60, 1.14, 1.33, 6.82, 0.10],
})

# %%
lsa_exprs = [
    'densenet',
    'maml',
    'maml+cifar10',
    'maml+mnist',
    'maml+ciarp',
    'maml+rwth',
    'tl+cifar10',
    'tl+mnist',
    'tl+ciarp',
    'tl+rwth',
    'protonet'
]

ciarp_exprs = [
    'densenet',
    'maml',
    'maml+cifar10',
    'maml+mnist',
    'maml+lsa16',
    'maml+rwth',
    'tl+cifar10',
    'tl+mnist',
    'tl+lsa16',
    'tl+rwth',
    'protonet'
]

rwth_exprs = [
    'densenet',
    'maml',
    'maml+cifar10',
    'maml+mnist',
    'maml+ciarp',
    'maml+lsa16',
    'tl+cifar10',
    'tl+mnist',
    'tl+ciarp',
    'tl+lsa16',
    'protonet'
]

# %%
fig, ax = plt.subplots(figsize=figsize)
df = lsa16.drop([0, 1])

ax = plt.axes()
# axes.set_ylim([80, 105])
ax.set_xticks(ticks=df.samples)

for expr in lsa_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('lsa16_15_30.png')

# %%
fig, ax = plt.subplots(figsize=figsize)
df = lsa16.drop([3, 4])

ax = plt.axes()
ax.set_ylim([80, 96])
ax.set_xticks(ticks=df.samples)

for expr in lsa_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('lsa16_5_15.png')

# %%
fig, ax = plt.subplots(figsize=figsize)
df = ciarp.drop([0, 1, 2, 3, 4])

ax = plt.axes()
ax.set_ylim([99.15, 100])
ax.set_xticks(ticks=df.samples)

for expr in ciarp_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('ciarp_40_360.png')

# %%
fig, ax = plt.subplots(figsize=figsize)
df = ciarp.drop([0, 1, 5, 6, 7])

ax = plt.axes()
ax.set_ylim([95, 100])
ax.set_xticks(ticks=df.samples)

for expr in ciarp_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('ciarp_15_40.png')

# %%
fig, ax = plt.subplots(figsize=figsize)
df = ciarp.drop([3, 4, 5, 6, 7])

ax = plt.axes()
# ax.set_ylim([99.15, 100])
ax.set_xticks(ticks=df.samples)

for expr in ciarp_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('ciarp_5_15.png')

# %%
fig, ax = plt.subplots(figsize=figsize)
df = rwth.drop([0, 1, 2])

ax = plt.axes()
# ax.set_ylim([99.15, 100])
ax.set_xticks(ticks=df.samples)

for expr in rwth_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('rwth_20_50.png')

# %%
fig, ax = plt.subplots(figsize=figsize)
df = rwth.drop([3, 4, 5, 6])

ax = plt.axes()
# ax.set_ylim([99.15, 100])
ax.set_xticks(ticks=df.samples)

for expr in rwth_exprs:
    # plt.errorbar('samples', f"{expr}_acc", f"{expr}_std", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)
    plt.plot('samples', f"{expr}_acc", label=labels[expr], data=df, marker='o', markerfacecolor=markerfacecolors[expr], markersize=2, color=colors[expr], linewidth=2)

plt.xlabel('number of samples')
plt.ylabel('accuracy')
plt.legend()
plt.savefig('rwth_5_15.png')
